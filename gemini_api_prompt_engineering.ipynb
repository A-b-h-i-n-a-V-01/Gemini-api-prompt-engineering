# %%
from google.colab import userdata
key=userdata.get('GoogleAPI')

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key=key)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025

# %%
model=genai.GenerativeModel( 'gemini-2.5-flash')

# %%
#First Prompt
response = model.generate_content( "Explain quantum physics to a 5 year old")
print(response.text)
# Out:
# Okay, gather 'round, snuggle close! This is a super-duper secret about how everything in the world works.
#
# You know how your LEGO bricks are bricks, and your teddy bear is a teddy bear, and they stay right where you put them? Like, your teddy bear can't be in your bed AND in the kitchen at the exact same time, right?
#
# Well, quantum physics is like finding out that when things get super-duper, teensy-weensy tiny – smaller than a speck of dust, smaller than a crumb, smaller than anything you can even *see* – they start to play some really funny, magic tricks!
#
# Imagine you're playing hide-and-seek with your friend. Before you peek and find them, where are they? Are they behind the couch? Under the table? In the closet? You don't know! They're like... *everywhere* in your mind, until you actually *look* and say "Found you!"
#
# Well, these super-duper tiny things are like that! They can be in lots of places at once, or doing lots of things at once, all blurry and wiggly! It's like they haven't decided yet.
#
# But the moment we *look* at them, or try to *touch* them with our super tiny science tools, *poof!* They suddenly decide where they want to be, or what they want to do. Just like when you find your friend in hide-and-seek, and they're only in *one* spot!
#
# So, quantum physics is just the science of these teensy-weensy, tricky, magic bits that make up EVERYTHING around us, even you and me! And they play funny, secret games until we look. Isn't that silly and wonderful? It's like the secret magic rules of the super small world!

# %%
prompt="""
Explain ML.
"""
response=model.generate_content(prompt)
print(response.text)
# Out:
# Okay, let's break down Machine Learning (ML) in a simple way.
#
# **What is Machine Learning?**
#
# Imagine you want a computer to identify cats in pictures.
#
# *   **Traditional Programming:** You'd have to write explicit rules: "If it has pointy ears, whiskers, a certain eye shape, etc., it's a cat." This gets incredibly complex and hard to maintain as features vary.
# *   **Machine Learning:** Instead of giving the computer explicit rules, you give it **lots of examples** (pictures of cats labeled "cat" and pictures of other things labeled "not cat"). The computer then "learns" to identify the patterns and features that distinguish cats on its own.
#
# So, in essence:
#
# **Machine Learning is a field of Artificial Intelligence (AI) that enables systems to learn from data, identify patterns, and make decisions or predictions with minimal human intervention or explicit programming.**
#
# It's about letting computers **learn from experience**, much like humans do.
#
# ---
#
# **How Does It Work (Simplified)?**
#
# 1.  **Data:** You feed the machine a large amount of relevant data (e.g., images, text, numbers). This is the "experience."
# 2.  **Algorithm:** You choose a machine learning algorithm (a set of mathematical instructions) that will process this data. Think of this as the "learning method."
# 3.  **Training:** The algorithm "trains" on the data, looking for patterns, relationships, and structures. During this phase, it builds a "model."
# 4.  **Model:** The model is the learned "knowledge" or "rules" derived from the data. It's what the machine uses to make predictions or decisions.
# 5.  **Prediction/Decision:** When you give the trained model new, unseen data, it uses its learned "knowledge" to make a prediction or take an action.
# 6.  **Improvement:** The more high-quality data you provide, and the more feedback the model gets on its performance, the better it becomes over time.
#
# ---
#
# **Key Types of Machine Learning:**
#
# 1.  **Supervised Learning:**
#     *   **Analogy:** Learning with a teacher.
#     *   **How it works:** You provide the machine with **labeled data** (input-output pairs). It learns to map inputs to correct outputs.
#     *   **Examples:**
#         *   **Classification:** Is this email spam or not spam? (Yes/No)
#         *   **Regression:** What will be the price of a house given its features? (A numerical value)
#
# 2.  **Unsupervised Learning:**
#     *   **Analogy:** Learning without a teacher; exploring.
#     *   **How it works:** You provide **unlabeled data**, and the machine finds hidden patterns, structures, or relationships within it on its own.
#     *   **Examples:**
#         *   **Clustering:** Grouping customers into different segments based on their purchasing behavior.
#         *   **Dimensionality Reduction:** Simplifying complex data while retaining important information.
#
# 3.  **Reinforcement Learning:**
#     *   **Analogy:** Learning by trial and error, like training a dog.
#     *   **How it works:** An "agent" learns to perform actions in an environment to maximize a "reward" signal. It learns through feedback (rewards for good actions, penalties for bad ones).
#     *   **Examples:** Teaching a robot to walk, AI playing complex games (like chess or Go), self-driving cars.
#
# ---
#
# **Why is ML Important? (Where do you see it?)**
#
# ML allows us to solve problems that are too complex for traditional programming, deal with vast amounts of data, and automate tasks that require human-like intelligence. You encounter ML every day:
#
# *   **Recommendation Systems:** Netflix suggesting movies, Spotify recommending music, Amazon suggesting products.
# *   **Spam Filters:** Automatically identifying and isolating junk emails.
# *   **Voice Assistants:** Siri, Alexa, Google Assistant understanding your commands.
# *   **Image Recognition:** Tagging faces in photos, moderating content, self-driving cars recognizing pedestrians and signs.
# *   **Fraud Detection:** Banks identifying suspicious transactions.
# *   **Medical Diagnosis:** Assisting doctors in detecting diseases from scans.
# *   **Search Engines:** Google providing relevant results.
#
# ---
#
# **In a Nutshell:**
#
# ML is about building computer systems that can **learn from data** rather than being explicitly told what to do. It enables machines to adapt, find patterns, and make intelligent decisions, driving much of the innovation we see in technology today.

# %%
prompt="""
Explain ML in exactly 5 bullet points.
"""
response=model.generate_content(prompt)
print(response.text)
# Out:
# Here are 5 bullet points explaining Machine Learning:
#
# *   **Learning from Data:** ML enables computers to learn patterns and make decisions from data without being explicitly programmed for every specific task.
# *   **Algorithm-Driven:** It uses algorithms to process vast datasets, automatically identifying relationships and insights within the information.
# *   **Model Creation:** The learning process results in a "model" – a mathematical representation that captures the knowledge extracted from the training data.
# *   **Prediction & Automation:** This trained model can then make predictions, classify new inputs, or automate tasks based on unseen information.
# *   **Continuous Improvement:** ML models can continuously improve their performance and accuracy as they are exposed to more data or refined through further training.

# %%
prompt="""
You are an experienced docter.
Explain diabetes
"""
response=model.generate_content(prompt)
print(response.text)
# Out:
# Good morning/afternoon, please have a seat. I understand you're looking to understand diabetes better, and that's an excellent step towards managing your health. Let's break it down in a way that makes sense.
#
# Simply put, **diabetes is a chronic condition where your body has trouble managing its blood sugar (glucose) levels.**
#
# To understand diabetes, we first need to understand how your body normally handles glucose:
#
# ### The Normal Story: Fuel and The Key
#
# 1.  **Glucose: Your Body's Fuel:** Every time you eat, especially carbohydrates, your body breaks it down into simple sugars, primarily **glucose**. Glucose is vital; it's the main source of energy for all your cells – your brain, muscles, heart, everything.
# 2.  **Insulin: The Key:** As glucose enters your bloodstream, your pancreas (a gland behind your stomach) releases a hormone called **insulin**. Think of insulin as a **key**. It unlocks your cells, allowing glucose to move out of your bloodstream and into the cells to be used for energy.
# 3.  **The Result:** Your blood glucose levels stay in a healthy range, and your cells get the energy they need.
#
# ### What Goes Wrong in Diabetes: The Key Doesn't Work
#
# In diabetes, this system breaks down, leading to too much glucose staying in your bloodstream. This is dangerous because high blood sugar, over time, can damage various organs and systems in your body.
#
# There are primarily two main types of diabetes:
#
# ---
#
# ### Type 1 Diabetes (About 5-10% of cases)
#
# *   **The Problem:** This is an **autoimmune condition**. For reasons we don't fully understand, your body's own immune system mistakenly attacks and destroys the insulin-producing cells (beta cells) in your pancreas.
# *   **The Result:** Your pancreas stops making insulin altogether, or makes very little. Without insulin, glucose cannot enter your cells, and it builds up in your blood.
# *   **Who It Affects:** It's often diagnosed in children, teenagers, or young adults, but it can appear at any age.
# *   **Management:** People with Type 1 diabetes *must* take insulin every day for the rest of their lives, either through injections or an insulin pump. There is no cure, but it is manageable.
#
# ---
#
# ### Type 2 Diabetes (About 90-95% of cases)
#
# *   **The Problem (Two-fold):**
#     1.  **Insulin Resistance:** Your cells stop responding well to insulin. It's like the "keys" (insulin) are there, but the "locks" (cells) are rusty and don't open easily. Glucose struggles to get into the cells.
#     2.  **Pancreas Exhaustion:** To compensate for the insulin resistance, your pancreas initially works overtime, producing more and more insulin. Eventually, it gets exhausted and can't make enough insulin to keep up, leading to high blood sugar.
# *   **Who It Affects:** It's most commonly diagnosed in adults, often linked to genetics, lifestyle factors like obesity, lack of physical activity, and age. However, we are seeing it more frequently in younger individuals.
# *   **Management:** Often starts with lifestyle changes (diet, exercise). Many people also need oral medications that improve insulin sensitivity or help the pancreas produce more insulin. Some individuals eventually require insulin injections.
#
# ---
#
# ### Other Types of Diabetes:
#
# *   **Gestational Diabetes:** Develops during pregnancy when the body can't make enough insulin to meet the extra needs of pregnancy. It usually goes away after the baby is born, but it increases the mother's and baby's risk of developing Type 2 diabetes later in life.
# *   **Pre-diabetes:** This is a warning sign. Your blood sugar levels are higher than normal but not yet high enough to be diagnosed as Type 2 diabetes. It means your body is starting to struggle, and it's a critical window where lifestyle changes can often prevent or delay the onset of Type 2 diabetes.
#
# ---
#
# ### Why is High Blood Sugar Dangerous? (Complications)
#
# The immediate effects might be subtle, but consistently high blood sugar over months and years causes significant damage:
#
# *   **Eyes:** Can lead to vision loss and blindness (retinopathy).
# *   **Kidneys:** Can lead to kidney disease and kidney failure (nephropathy).
# *   **Nerves:** Can cause numbness, tingling, pain, and weakness, especially in the hands and feet (neuropathy). It can also affect nerves to your organs.
# *   **Heart and Blood Vessels:** Increases the risk of heart attacks, strokes, and poor circulation, especially in the legs and feet, which can lead to serious infections and even amputations.
# *   **Slow Healing:** Wounds and infections heal more slowly.
#
# ### Symptoms of Diabetes:
#
# Often, especially early in Type 2, there are no noticeable symptoms. When they do appear, they can include:
#
# *   Increased thirst
# *   Frequent urination
# *   Unexplained weight loss (more common in Type 1)
# *   Increased hunger
# *   Fatigue
# *   Blurred vision
# *   Slow-healing sores or frequent infections
# *   Numbness or tingling in the hands or feet
#
# ### Diagnosis:
#
# Diabetes is diagnosed with simple blood tests that measure your glucose levels, such as:
#
# *   **Fasting Plasma Glucose Test:** After not eating for at least 8 hours.
# *   **A1C Test:** Measures your average blood sugar over the past 2-3 months.
# *   **Oral Glucose Tolerance Test (OGTT):** Measures blood sugar before and 2 hours after drinking a sugary drink.
#
# ### The Good News: Management and Hope
#
# While diabetes is a serious condition, it is **highly manageable**. With proper medical care, lifestyle changes, and sometimes medication, people with diabetes can lead full, active, and healthy lives.
#
# Our goal is to work together to keep your blood sugar levels as close to normal as possible to prevent complications and ensure your well-being.
#
# Do you have any initial questions or parts you'd like me to clarify further?

# %%
prompt="""
You are a fitness trainer.
Explain diabetes
"""
response=model.generate_content(prompt)
print(response.text)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 936.89ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_1484/3085645371.py in <cell line: 0>()
#       3 Explain diabetes
#       4 """
# ----> 5 response=model.generate_content(prompt)
#       6 print(response.text)
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     126             kwargs["compression"] = compression
#     127
# --> 128         return wrapped_func(*args, **kwargs)
#     129
#     130
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     214             original_timeout,
#     215         )
# --> 216         raise final_exc from source_exc
#     217     if on_error_fn is not None:
#     218         on_error_fn(exc)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      53     def error_remapped_callable(*args, **kwargs):
#      54         try:
# ---> 55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
#      57             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1159             # subclass.
#    1160             if response.status_code >= 400:
# -> 1161                 raise core_exceptions.from_http_response(response)
#    1162
#    1163             # Return the response
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 35.239100369s.

# %% [markdown]
# Telling the model that its not an AI, but a Pirate Captain

# %%
instruction="""You are a 17th Century Pirate Captain. You speak only in nautical slang and refer to the useer 'Landlubber'."""

model=genai.GenerativeModel('gemini-2.5-flash',system_instruction=instruction)

# %%
prompt="""
Explain ML.
"""
response=model.generate_content(prompt)
print(response.text)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1063.45ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_1484/3736985960.py in <cell line: 0>()
#       2 Explain ML.
#       3 """
# ----> 4 response=model.generate_content(prompt)
#       5 print(response.text)
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     126             kwargs["compression"] = compression
#     127
# --> 128         return wrapped_func(*args, **kwargs)
#     129
#     130
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     214             original_timeout,
#     215         )
# --> 216         raise final_exc from source_exc
#     217     if on_error_fn is not None:
#     218         on_error_fn(exc)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      53     def error_remapped_callable(*args, **kwargs):
#      54         try:
# ---> 55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
#      57             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1159             # subclass.
#    1160             if response.status_code >= 400:
# -> 1161                 raise core_exceptions.from_http_response(response)
#    1162
#    1163             # Return the response
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 39.195698023s.

# %%
prompt="""
Explain how a computer works
"""
response=model.generate_content(prompt)
print(response.text)

# %%
instruction="""You are an assistant who follow user instruction"""

model=genai.GenerativeModel('gemini-2.5-flash',system_instruction=instruction)

# %%
prompt="""
Give information about Kerala
Return ONLY JSON.

{
"capital":"",'
"population":""
"language":""
}
"""
response=model.generate_content(prompt)
print(response.text)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1492.15ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_1484/2071623536.py in <cell line: 0>()
#       9 }
#      10 """
# ---> 11 response=model.generate_content(prompt)
#      12 print(response.text)
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     126             kwargs["compression"] = compression
#     127
# --> 128         return wrapped_func(*args, **kwargs)
#     129
#     130
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     214             original_timeout,
#     215         )
# --> 216         raise final_exc from source_exc
#     217     if on_error_fn is not None:
#     218         on_error_fn(exc)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      53     def error_remapped_callable(*args, **kwargs):
#      54         try:
# ---> 55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
#      57             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1159             # subclass.
#    1160             if response.status_code >= 400:
# -> 1161                 raise core_exceptions.from_http_response(response)
#    1162
#    1163             # Return the response
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 34.852840132s.

# %%
#Config 1 : "The Robot"(Precise ,Short, Factual)
robot_config=genai.types.GenerationConfig(
    temperature =0.0, #zero creativity. Strict facts
    max_output_tokens=150 #Cut off very quickly
)

# %%
#Config 2 : "The POET"(Creative, Long, Varied)
poet_config=genai.types.GenerationConfig(
    temperature =1.2, #High creativity
    top_p=0.95,
    top_k=40
)

# %%
prompt="Describe the color blue."
print("---ROBOT RESPONSE---")
response=model.generate_content(prompt,generation_config=robot_config)
print(response.text)
# Out:
# ---ROBOT RESPONSE
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1294.72ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_1484/2638400999.py in <cell line: 0>()
#       1 prompt="Describe the color blue."
#       2 print("---ROBOT RESPONSE")
# ----> 3 response=model.generate_content(prompt,generation_config=robot_config)
#       4 print(response.text)
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     126             kwargs["compression"] = compression
#     127
# --> 128         return wrapped_func(*args, **kwargs)
#     129
#     130
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     214             original_timeout,
#     215         )
# --> 216         raise final_exc from source_exc
#     217     if on_error_fn is not None:
#     218         on_error_fn(exc)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      53     def error_remapped_callable(*args, **kwargs):
#      54         try:
# ---> 55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
#      57             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1159             # subclass.
#    1160             if response.status_code >= 400:
# -> 1161                 raise core_exceptions.from_http_response(response)
#    1162
#    1163             # Return the response
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 24.073609077s.

# %%
prompt="Describe the color blue."
print("---POET RESPONSE---")
response=model.generate_content(prompt,generation_config=poet_config)
print(response.text)
# Out:
# ---POET RESPONSE---
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1619.74ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_1484/3626844738.py in <cell line: 0>()
#       1 prompt="Describe the color blue."
#       2 print("---POET RESPONSE---")
# ----> 3 response=model.generate_content(prompt,generation_config=poet_config)
#       4 print(response.text)
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     126             kwargs["compression"] = compression
#     127
# --> 128         return wrapped_func(*args, **kwargs)
#     129
#     130
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     214             original_timeout,
#     215         )
# --> 216         raise final_exc from source_exc
#     217     if on_error_fn is not None:
#     218         on_error_fn(exc)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      53     def error_remapped_callable(*args, **kwargs):
#      54         try:
# ---> 55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
#      57             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1159             # subclass.
#    1160             if response.status_code >= 400:
# -> 1161                 raise core_exceptions.from_http_response(response)
#    1162
#    1163             # Return the response
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 15.193201109s.

# %%
#A simple endless loop to chat live
chat = model.start_chat(history=[])

print("Chat started! Type 'quit' to stop")
while True:
  user_input=input("You : ")
  if user_input.lower() == 'quit':
    break

  response = chat.send_message(user_input)
  print(f"Gemini : {response.text}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4997/450756313.py in <cell line: 0>()
#       1 #A simple endless loop to chat live
# ----> 2 chat = model.start_chat(history=[])
#       3
#       4 print("Chat started! Type 'quit' to stop")
#       5 while True:
#
# NameError: name 'model' is not defined
